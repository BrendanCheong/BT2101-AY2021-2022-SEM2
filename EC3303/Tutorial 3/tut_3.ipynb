# %%
import numpy as np
import scipy as sp
import statsmodels.formula.api as smf
import statsmodels.api as sm
import pandas as pd
import seaborn as sns
import wooldridge
from typing import *
from statsmodels.tools.eval_measures import rmse
sns.set(rc={'figure.figsize':(11.7,8.27)})

df = pd.read_stata("caschool.dta")
df
# Out:
#      observat  dist_cod       county                         district gr_span  \
# 0         1.0   75119.0      Alameda               Sunol Glen Unified   KK-08
# 1         2.0   61499.0        Butte             Manzanita Elementary   KK-08
# 2         3.0   61549.0        Butte      Thermalito Union Elementary   KK-08
# 3         4.0   61457.0        Butte  Golden Feather Union Elementary   KK-08
# 4         5.0   61523.0        Butte         Palermo Union Elementary   KK-08
# ..        ...       ...          ...                              ...     ...
# 415     416.0   68957.0    San Mateo           Las Lomitas Elementary   KK-08
# 416     417.0   69518.0  Santa Clara             Los Altos Elementary   KK-08
# 417     418.0   72611.0      Ventura           Somis Union Elementary   KK-08
# 418     419.0   72744.0         Yuba                Plumas Elementary   KK-08
# 419     420.0   72751.0         Yuba             Wheatland Elementary   KK-08
#
# ...
